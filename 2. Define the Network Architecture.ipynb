# %% [markdown]
# ## Define the Convolutional Neural Network
#
# After you've looked at the data you're working with and, in this case, know the shapes of the images and of the keypoints, you are ready to define a convolutional neural network that can *learn* from this data.
#
# In this notebook and in `models.py`, you will:
# 1. Define a CNN with images as input and keypoints as output
# 2. Construct the transformed FaceKeypointsDataset, just as before
# 3. Train the CNN on the training data, tracking loss
# 4. See how the trained model performs on test data
# 5. If necessary, modify the CNN structure and model hyperparameters, so that it performs *well* **\***
#
# **\*** What does *well* mean?
#
# "Well" means that the model's loss decreases during training **and**, when applied to test image data, the model produces keypoints that closely match the true keypoints of each face. And you'll see examples of this later in the notebook.
#
# ---

# %% [markdown]
# ## CNN Architecture
#
# Recall that CNN's are defined by a few types of layers:
# * Convolutional layers
# * Maxpooling layers
# * Fully-connected layers
#
# You are required to use the above layers and encouraged to add multiple convolutional layers and things like dropout layers that may prevent overfitting. You are also encouraged to look at literature on keypoint detection, such as [this paper](https://arxiv.org/pdf/1710.00977.pdf), to help you determine the structure of your network.
#
#
# ### TODO: Define your model in the provided file `models.py` file
#
# This file is mostly empty but contains the expected name and some TODO's for creating your model.
#
# ---

# %% [markdown]
# ## PyTorch Neural Nets
#
# To define a neural network in PyTorch, you define the layers of a model in the function `__init__` and define the feedforward behavior of a network that employs those initialized layers in the function `forward`, which takes in an input image tensor, `x`. The structure of this Net class is shown below and left for you to fill in.
#
# Note: During training, PyTorch will be able to perform backpropagation by keeping track of the network's feedforward behavior and using autograd to calculate the update to the weights in the network.
#
# #### Define the Layers in ` __init__`
# As a reminder, a conv/pool layer may be defined like this (in `__init__`):
# ```
# # 1 input image channel (for grayscale images), 32 output channels/feature maps, 3x3 square convolution kernel
# self.conv1 = nn.Conv2d(1, 32, 3)
#
# # maxpool that uses a square window of kernel_size=2, stride=2
# self.pool = nn.MaxPool2d(2, 2)
# ```
#
# #### Refer to Layers in `forward`
# Then referred to in the `forward` function like this, in which the conv1 layer has a ReLu activation applied to it before maxpooling is applied:
# ```
# x = self.pool(F.relu(self.conv1(x)))
# ```
#
# Best practice is to place any layers whose weights will change during the training process in `__init__` and refer to them in the `forward` function; any layers or functions that always behave in the same way, such as a pre-defined activation function, should appear *only* in the `forward` function.

# %% [markdown]
# #### Why models.py
#
# You are tasked with defining the network in the `models.py` file so that any models you define can be saved and loaded by name in different notebooks in this project directory. For example, by defining a CNN class called `Net` in `models.py`, you can then create that same architecture in this and other notebooks by simply importing the class and instantiating a model:
# ```
#     from models import Net
#     net = Net()
# ```

# %%
import platform
from pathlib import Path
running_os = platform.platform().split('-')[0].lower()
if 'windows' in running_os:
    root = Path('data')
else:
    root = Path('/data')

if not root.exists():
    # load the data if you need to; if you have already loaded the data, you may comment this cell out
    # -- DO NOT CHANGE THIS CELL -- #
    # !mkdir /data
    # !wget -P /data/ https://s3.amazonaws.com/video.udacity-data.com/topher/2018/May/5aea1b91_train-test-data/train-test-data.zip
    # !unzip -n /data/train-test-data.zip -d /data
else:
    print('Directory found, not loading...')
# Out:
# Directory found, not loading...

# %%
# load the data if you need to; if you have already loaded the data, you may comment this cell out
# -- DO NOT CHANGE THIS CELL -- #
# !mkdir /data
# !wget -P /data/ https://s3.amazonaws.com/video.udacity-data.com/topher/2018/May/5aea1b91_train-test-data/train-test-data.zip
# !unzip -n /data/train-test-data.zip -d /data

# %% [markdown]
# <div class="alert alert-info">**Note:** Workspaces automatically close connections after 30 minutes of inactivity (including inactivity while training!). Use the code snippet below to keep your workspace alive during training. (The active_session context manager is imported below.)
# </div>
#
# ```
# from workspace_utils import active_session
#
# with active_session():
#     train_model(num_epochs)
# ```

# %%
# import the usual resources
import matplotlib.pyplot as plt
import numpy as np

# import utilities to keep workspaces alive during model training
from workspace_utils import active_session

# watch for any changes in model.py, if it changes, re-load it automatically
# %load_ext autoreload
# %autoreload 2

# %%
## TODOne: Define the Net in models.py

import torch
import torch.nn as nn
import torch.nn.functional as F

## TODOne: Once you've define the network, you can instantiate it
# one example conv layer has been provided for you
from models import Net

N_INPUT = 224
net = Net(
    n_input=N_INPUT,
    conv_structure=(32, 36, 48, 64, 64),
    kernel_sizes=(5, 5, 5, 3, 3),
    fc_structure=(),
    p_drop_init=0.0,
    max_p_drop=0.0,
)
print(net)
# Out:
# Net(
#   (act_f): ReLU()
#   (conv): ModuleList(
#     (0): Sequential(
#       (0): Conv2d(1, 32, kernel_size=(5, 5), stride=(1, 1))
#       (1): ReLU()
#       (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (3): Dropout(p=0.0, inplace=False)
#     )
#     (1): Sequential(
#       (0): Conv2d(32, 36, kernel_size=(5, 5), stride=(1, 1))
#       (1): ReLU()
#       (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (3): Dropout(p=0.0, inplace=False)
#     )
#     (2): Sequential(
#       (0): Conv2d(36, 48, kernel_size=(5, 5), stride=(1, 1))
#       (1): ReLU()
#       (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (3): Dropout(p=0.0, inplace=False)
#     )
#     (3): Sequential(
#       (0): Conv2d(48, 64, kernel_size=(3, 3), stride=(1, 1))
#       (1): ReLU()
#       (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (3): Dropout(p=0.0, inplace=False)
#     )
#     (4): Sequential(
#       (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1))
#       (1): ReLU()
#       (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (3): Dropout(p=0.0, inplace=False)
#     )
#   )
#   (dense): ModuleList(
#     (0): Sequential(
#       (0): Linear(in_features=1024, out_features=136, bias=True)
#     )
#   )
# )

# %% [markdown]
# ## Transform the dataset
#
# To prepare for training, create a transformed dataset of images and keypoints.
#
# ### TODO: Define a data transform
#
# In PyTorch, a convolutional neural network expects a torch image of a consistent size as input. For efficient training, and so your model's loss does not blow up during training, it is also suggested that you normalize the input images and keypoints. The necessary transforms have been defined in `data_load.py` and you **do not** need to modify these; take a look at this file (you'll see the same transforms that were defined and applied in Notebook 1).
#
# To define the data transform below, use a [composition](http://pytorch.org/tutorials/beginner/data_loading_tutorial.html#compose-transforms) of:
# 1. Rescaling and/or cropping the data, such that you are left with a square image (the suggested size is 224x224px)
# 2. Normalizing the images and keypoints; turning each RGB image into a grayscale image with a color range of [0, 1] and transforming the given keypoints into a range of [-1, 1]
# 3. Turning these images and keypoints into Tensors
#
# These transformations have been defined in `data_load.py`, but it's up to you to call them and create a `data_transform` below. **This transform will be applied to the training data and, later, the test data**. It will change how you go about displaying these images and keypoints, but these steps are essential for efficient training.
#
# As a note, should you want to perform data augmentation (which is optional in this project), and randomly rotate or shift these images, a square image size will be useful; rotating a 224x224 image by 90 degrees will result in the same shape of output.

# %%
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms, utils

# the dataset we created in Notebook 1 is copied in the helper file `data_load.py`
from data_load import FacialKeypointsDataset
# the transforms we defined in Notebook 1 are in the helper file `data_load.py`
from data_load import Rescale, RandomCrop, Normalize, ToTensor, RandomRotate


## TODO: define the data_transform using transforms.Compose([all tx's, . , .])
# order matters! i.e. rescaling should come before a smaller crop
N_RESCALE = 250

data_transform = transforms.Compose([
    Rescale(N_RESCALE),
    RandomCrop(N_INPUT),
    # RandomRotate(),
    Normalize(),
    ToTensor(),
])

# testing that you've defined a transform
assert(data_transform is not None), 'Define a data_transform'

# %%
# create the transformed dataset
transformed_dataset = FacialKeypointsDataset(csv_file=root / 'training_frames_keypoints.csv',
                                             root_dir=root / 'training/',
                                             transform=data_transform)


print('Number of images: ', len(transformed_dataset))

# iterate through the transformed dataset and print some stats about the first few samples
for i in range(4):
    sample = transformed_dataset[i]
    print(i, sample['image'].size(), sample['keypoints'].size())
# Out:
# Number of images:  3462
# 0 torch.Size([1, 224, 224]) torch.Size([68, 2])
# 1 torch.Size([1, 224, 224]) torch.Size([68, 2])
# 2 torch.Size([1, 224, 224]) torch.Size([68, 2])
# 3 torch.Size([1, 224, 224]) torch.Size([68, 2])

# %% [markdown]
# ## Batching and loading data
#
# Next, having defined the transformed dataset, we can use PyTorch's DataLoader class to load the training data in batches of whatever size as well as to shuffle the data for training the model. You can read more about the parameters of the DataLoader, in [this documentation](http://pytorch.org/docs/master/data.html).
#
# #### Batch size
# Decide on a good batch size for training your model. Try both small and large batch sizes and note how the loss decreases as the model trains. Too large a batch size may cause your model to crash and/or run out of memory while training.
#
# **Note for Windows users**: Please change the `num_workers` to 0 or you may face some issues with your DataLoader failing.

# %%
# load training data in batches
batch_size = 10

train_loader = DataLoader(transformed_dataset, 
                          batch_size=batch_size,
                          shuffle=True, 
                          num_workers=4)

# %% [markdown]
# ## Before training
#
# Take a look at how this model performs before it trains. You should see that the keypoints it predicts start off in one spot and don't match the keypoints on a face at all! It's interesting to visualize this behavior so that you can compare it to the model after training and see how the model has improved.
#
# #### Load in the test dataset
#
# The test dataset is one that this model has *not* seen before, meaning it has not trained with these images. We'll load in this test data and before and after training, see how your model performs on this set!
#
# To visualize this test data, we have to go through some un-transformation steps to turn our images into python images from tensors and to turn our keypoints back into a recognizable range.

# %%
# load in the test data, using the dataset class
# AND apply the data_transform you defined above

# create the test dataset
test_dataset = FacialKeypointsDataset(csv_file=root / 'test_frames_keypoints.csv',
                                      root_dir=root / 'test/',
                                      transform=data_transform)

# %%
# load test data in batches
# batch_size = 50

test_loader = DataLoader(test_dataset, 
                          batch_size=batch_size,
                          shuffle=True, 
                          num_workers=4)

# %% [markdown]
# ## Apply the model on a test sample
#
# To test the model on a test sample of data, you have to follow these steps:
# 1. Extract the image and ground truth keypoints from a sample
# 2. Wrap the image in a Variable, so that the net can process it as input and track how it changes as the image moves through the network.
# 3. Make sure the image is a FloatTensor, which the model expects.
# 4. Forward pass the image through the net to get the predicted, output keypoints.
#
# This function test how the network performs on the first batch of test data. It returns the images, the transformed images, the predicted keypoints (produced by the model), and the ground truth keypoints.

# %%
# test the model on a batch of test images

def net_sample_output():
    
    # iterate through the test dataset
    for i, sample in enumerate(test_loader):
        
        # get sample data: images and ground truth keypoints
        images = sample['image']
        key_pts = sample['keypoints']

        # convert images to FloatTensors
        images = images.type(torch.FloatTensor)

        # forward pass to get net output
        output_pts = net(images)
        
        # reshape to batch_size x 68 x 2 pts
        output_pts = output_pts.view(output_pts.size()[0], 68, -1)
        
        # break after first image is tested
        if i == 0:
            return images, output_pts, key_pts

# %% [markdown]
# #### Debugging tips
#
# If you get a size or dimension error here, make sure that your network outputs the expected number of keypoints! Or if you get a Tensor type error, look into changing the above code that casts the data into float types: `images = images.type(torch.FloatTensor)`.

# %%
# call the above function
# returns: test images, test predicted keypoints, test ground truth keypoints
test_images, test_outputs, gt_pts = net_sample_output()

# print out the dimensions of the data to see if they make sense
print(test_images.data.size())
print(test_outputs.data.size())
print(gt_pts.size())
# Out:
# torch.Size([10, 1, 224, 224])
# torch.Size([10, 68, 2])
# torch.Size([10, 68, 2])

# %% [markdown]
# ## Visualize the predicted keypoints
#
# Once we've had the model produce some predicted output keypoints, we can visualize these points in a way that's similar to how we've displayed this data before, only this time, we have to "un-transform" the image/keypoint data to display it.
#
# Note that I've defined a *new* function, `show_all_keypoints` that displays a grayscale image, its predicted keypoints and its ground truth keypoints (if provided).

# %%
def show_all_keypoints(image, predicted_key_pts, gt_pts=None):
    """Show image with predicted keypoints"""
    # image is grayscale
    plt.imshow(image, cmap='gray')
    plt.scatter(predicted_key_pts[:, 0], predicted_key_pts[:, 1], s=20, marker='.', c='m')
    # plot ground truth points as green pts
    if gt_pts is not None:
        plt.scatter(gt_pts[:, 0], gt_pts[:, 1], s=20, marker='.', c='g')

# %% [markdown]
# #### Un-transformation
#
# Next, you'll see a helper function. `visualize_output` that takes in a batch of images, predicted keypoints, and ground truth keypoints and displays a set of those images and their true/predicted keypoints.
#
# This function's main role is to take batches of image and keypoint data (the input and output of your CNN), and transform them into numpy images and un-normalized keypoints (x, y) for normal display. The un-transformation process turns keypoints and images into numpy arrays from Tensors *and* it undoes the keypoint normalization done in the Normalize() transform; it's assumed that you applied these transformations when you loaded your test data.

# %%
# visualize the output
# by default this shows a batch of 10 images
def visualize_output(test_images, test_outputs, gt_pts=None, batch_size=10):

    for i in range(batch_size):
        plt.figure(figsize=(20,10))
        ax = plt.subplot(1, batch_size, i+1)

        # un-transform the image data
        image = test_images[i].data   # get the image from it's Variable wrapper
        image = image.numpy()   # convert to numpy array from a Tensor
        image = np.transpose(image, (1, 2, 0))   # transpose to go from torch to numpy image

        # un-transform the predicted key_pts data
        predicted_key_pts = test_outputs[i].data
        predicted_key_pts = predicted_key_pts.numpy()
        # undo normalization of keypoints  
        predicted_key_pts = predicted_key_pts*50.0+100
        
        # plot ground truth points for comparison, if they exist
        ground_truth_pts = None
        if gt_pts is not None:
            ground_truth_pts = gt_pts[i]         
            ground_truth_pts = ground_truth_pts*50.0+100
        
        # call show_all_keypoints
        show_all_keypoints(np.squeeze(image), predicted_key_pts, ground_truth_pts)
            
        plt.axis('off')

    plt.show()

# %%
 
# call it
visualize_output(test_images, test_outputs, gt_pts)

# %% [markdown]
# ## Training
#
# #### Loss function
# Training a network to predict keypoints is different than training a network to predict a class; instead of outputting a distribution of classes and using cross entropy loss, you may want to choose a loss function that is suited for regression, which directly compares a predicted value and target value. Read about the various kinds of loss functions (like MSE or L1/SmoothL1 loss) in [this documentation](http://pytorch.org/docs/master/_modules/torch/nn/modules/loss.html).
#
# ### TODO: Define the loss and optimization
#
# Next, you'll define how the model will train by deciding on the loss function and optimizer.
#
# ---

# %%
## TODO: Define the loss and optimization
import torch.optim as optim
# Initially based on https://arxiv.org/pdf/1710.00977.pdf
criterion = nn.MSELoss()

# optimizer = optim.Adam(net.parameters(), lr=1e-3, betas=(0.9, 0.999))
optimizer = optim.Adam(net.parameters(), lr=1e-4)

# %% [markdown]
# ## Training and Initial Observation
#
# Now, you'll train on your batched training data from `train_loader` for a number of epochs.
#
# To quickly observe how your model is training and decide on whether or not you should modify it's structure or hyperparameters, you're encouraged to start off with just one or two epochs at first. As you train, note how your the model's loss behaves over time: does it decrease quickly at first and then slow down? Does it take a while to decrease in the first place? What happens if you change the batch size of your training data or modify your loss function? etc.
#
# Use these initial observations to make changes to your model and decide on the best architecture before you train for many epochs and create a final model.

# %%
def train_net(n_epochs, net, loader):
    
    to_cuda = torch.cuda.is_available()
    if to_cuda:
        net = net.cuda()

    # prepare the net for training
    net.train()

    losses = []
    for epoch in range(n_epochs):  # loop over the dataset multiple times
        
        running_loss = 0.0

        # train on batches of data, assumes you already have train_loader
        for batch_i, data in enumerate(loader['train']):
            # get the input images and their corresponding labels
            images = data['image']
            key_pts = data['keypoints']

            # flatten pts
            key_pts = key_pts.view(key_pts.size(0), -1)

            # convert variables to floats for regression loss
            key_pts = key_pts.type(torch.FloatTensor)
            images = images.type(torch.FloatTensor)

            if to_cuda:
                images, key_pts = images.cuda(), key_pts.cuda()

            # forward pass to get outputs
            output_pts = net(images)

            # calculate the loss between predicted and target keypoints
            loss = criterion(output_pts, key_pts)

            # zero the parameter (weight) gradients
            optimizer.zero_grad()

            
            # backward pass to calculate the weight gradients
            loss.backward()

            # update the weights
            optimizer.step()

            # print loss statistics
            running_loss += loss.item()

            print_every = 10
            if (batch_i+1) % print_every == 0:    # print every 10 batches
                avg_loss = running_loss / print_every
                e = epoch + 1
                batch = batch_i + 1
                print(f'Epoch: {e:> 3d}, Batch: {batch:< 4d}, '
                      f'Avg. Loss: {avg_loss:.5f}')
                losses.append(avg_loss)
                running_loss = 0.0

    print('Finished Training')
    return losses

# %%
# train your network
# start small, and increase when you've decided on your model structure and
# hyperparams
n_epochs = 30

loader = {'train': train_loader, 'test': test_loader}
# this is a Workspaces-specific context manager to keep the connection
# alive while training your model, not part of pytorch
if 'windows' not in running_os:
    with active_session():
        losses = train_net(n_epochs=n_epochs, net=net, loader=loader)
else:
    losses = train_net(n_epochs=n_epochs, net=net, loader=loader)
# Out:
# Epoch:   1, Batch:  10 , Avg. Loss: 0.58728
# Epoch:   1, Batch:  20 , Avg. Loss: 0.55222
# Epoch:   1, Batch:  30 , Avg. Loss: 0.53868
# Epoch:   1, Batch:  40 , Avg. Loss: 0.29706
# Epoch:   1, Batch:  50 , Avg. Loss: 0.22983
# Epoch:   1, Batch:  60 , Avg. Loss: 0.16112
# Epoch:   1, Batch:  70 , Avg. Loss: 0.19479
# Epoch:   1, Batch:  80 , Avg. Loss: 0.20579
# Epoch:   1, Batch:  90 , Avg. Loss: 0.21178
# Epoch:   1, Batch:  100, Avg. Loss: 0.17212
# Epoch:   1, Batch:  110, Avg. Loss: 0.15920
# Epoch:   1, Batch:  120, Avg. Loss: 0.20191
# Epoch:   1, Batch:  130, Avg. Loss: 0.18287
# Epoch:   1, Batch:  140, Avg. Loss: 0.20956
# Epoch:   1, Batch:  150, Avg. Loss: 0.18773
# Epoch:   1, Batch:  160, Avg. Loss: 0.17226
# Epoch:   1, Batch:  170, Avg. Loss: 0.17078
# Epoch:   1, Batch:  180, Avg. Loss: 0.17346
# Epoch:   1, Batch:  190, Avg. Loss: 0.18049
# Epoch:   1, Batch:  200, Avg. Loss: 0.23833
# Epoch:   1, Batch:  210, Avg. Loss: 0.21307
# Epoch:   1, Batch:  220, Avg. Loss: 0.16105
# Epoch:   1, Batch:  230, Avg. Loss: 0.19154
# Epoch:   1, Batch:  240, Avg. Loss: 0.17373
# Epoch:   1, Batch:  250, Avg. Loss: 0.19464
# Epoch:   1, Batch:  260, Avg. Loss: 0.15002
# Epoch:   1, Batch:  270, Avg. Loss: 0.19881
# Epoch:   1, Batch:  280, Avg. Loss: 0.15868
# Epoch:   1, Batch:  290, Avg. Loss: 0.16441
# Epoch:   1, Batch:  300, Avg. Loss: 0.18416
# Epoch:   1, Batch:  310, Avg. Loss: 0.18930
# Epoch:   1, Batch:  320, Avg. Loss: 0.16660
# Epoch:   1, Batch:  330, Avg. Loss: 0.30978
# Epoch:   1, Batch:  340, Avg. Loss: 0.16620
# Epoch:   2, Batch:  10 , Avg. Loss: 0.17103
# Epoch:   2, Batch:  20 , Avg. Loss: 0.24158
# Epoch:   2, Batch:  30 , Avg. Loss: 0.20924
# Epoch:   2, Batch:  40 , Avg. Loss: 0.22734
# Epoch:   2, Batch:  50 , Avg. Loss: 0.21557
# Epoch:   2, Batch:  60 , Avg. Loss: 0.14061
# Epoch:   2, Batch:  70 , Avg. Loss: 0.14032
# Epoch:   2, Batch:  80 , Avg. Loss: 0.19460
# Epoch:   2, Batch:  90 , Avg. Loss: 0.15906
# Epoch:   2, Batch:  100, Avg. Loss: 0.16667
# Epoch:   2, Batch:  110, Avg. Loss: 0.18497
# Epoch:   2, Batch:  120, Avg. Loss: 0.12824
# Epoch:   2, Batch:  130, Avg. Loss: 0.15999
# Epoch:   2, Batch:  140, Avg. Loss: 0.19278
# Epoch:   2, Batch:  150, Avg. Loss: 0.18839
# Epoch:   2, Batch:  160, Avg. Loss: 0.17236
# Epoch:   2, Batch:  170, Avg. Loss: 0.18755
# Epoch:   2, Batch:  180, Avg. Loss: 0.16439
# Epoch:   2, Batch:  190, Avg. Loss: 0.17653
# Epoch:   2, Batch:  200, Avg. Loss: 0.19288
# Epoch:   2, Batch:  210, Avg. Loss: 0.26255
# Epoch:   2, Batch:  220, Avg. Loss: 0.18773
# Epoch:   2, Batch:  230, Avg. Loss: 0.20927
# Epoch:   2, Batch:  240, Avg. Loss: 0.28369
# Epoch:   2, Batch:  250, Avg. Loss: 0.18143
# Epoch:   2, Batch:  260, Avg. Loss: 0.18642
# Epoch:   2, Batch:  270, Avg. Loss: 0.23208
# Epoch:   2, Batch:  280, Avg. Loss: 0.17257
# Epoch:   2, Batch:  290, Avg. Loss: 0.19022
# Epoch:   2, Batch:  300, Avg. Loss: 0.21435
# Epoch:   2, Batch:  310, Avg. Loss: 0.15817
# Epoch:   2, Batch:  320, Avg. Loss: 0.20347
# Epoch:   2, Batch:  330, Avg. Loss: 0.16946
# Epoch:   2, Batch:  340, Avg. Loss: 0.19950
# Epoch:   3, Batch:  10 , Avg. Loss: 0.33854
# Epoch:   3, Batch:  20 , Avg. Loss: 0.17686
# Epoch:   3, Batch:  30 , Avg. Loss: 0.18658
# Epoch:   3, Batch:  40 , Avg. Loss: 0.18674
# Epoch:   3, Batch:  50 , Avg. Loss: 0.23804
# Epoch:   3, Batch:  60 , Avg. Loss: 0.17342
# Epoch:   3, Batch:  70 , Avg. Loss: 0.16844
# Epoch:   3, Batch:  80 , Avg. Loss: 0.17582
# Epoch:   3, Batch:  90 , Avg. Loss: 0.20461
# Epoch:   3, Batch:  100, Avg. Loss: 0.16757
# Epoch:   3, Batch:  110, Avg. Loss: 0.15488
# Epoch:   3, Batch:  120, Avg. Loss: 0.19715
# Epoch:   3, Batch:  130, Avg. Loss: 0.20991
# Epoch:   3, Batch:  140, Avg. Loss: 0.17357
# Epoch:   3, Batch:  150, Avg. Loss: 0.14461
# Epoch:   3, Batch:  160, Avg. Loss: 0.15412
# Epoch:   3, Batch:  170, Avg. Loss: 0.18289
# Epoch:   3, Batch:  180, Avg. Loss: 0.20379
# Epoch:   3, Batch:  190, Avg. Loss: 0.16313
# Epoch:   3, Batch:  200, Avg. Loss: 0.16701
# Epoch:   3, Batch:  210, Avg. Loss: 0.18246
# Epoch:   3, Batch:  220, Avg. Loss: 0.15721
# Epoch:   3, Batch:  230, Avg. Loss: 0.14287
# Epoch:   3, Batch:  240, Avg. Loss: 0.22203
# Epoch:   3, Batch:  250, Avg. Loss: 0.17097
# Epoch:   3, Batch:  260, Avg. Loss: 0.21706
# Epoch:   3, Batch:  270, Avg. Loss: 0.16202
# Epoch:   3, Batch:  280, Avg. Loss: 0.21930
# Epoch:   3, Batch:  290, Avg. Loss: 0.19001
# Epoch:   3, Batch:  300, Avg. Loss: 0.28521
# Epoch:   3, Batch:  310, Avg. Loss: 0.14704
# Epoch:   3, Batch:  320, Avg. Loss: 0.20786
# Epoch:   3, Batch:  330, Avg. Loss: 0.18185
# Epoch:   3, Batch:  340, Avg. Loss: 0.15719
# Epoch:   4, Batch:  10 , Avg. Loss: 0.18112
# Epoch:   4, Batch:  20 , Avg. Loss: 0.17724
# Epoch:   4, Batch:  30 , Avg. Loss: 0.14393
# Epoch:   4, Batch:  40 , Avg. Loss: 0.17310
# Epoch:   4, Batch:  50 , Avg. Loss: 0.17672
# Epoch:   4, Batch:  60 , Avg. Loss: 0.22200
# Epoch:   4, Batch:  70 , Avg. Loss: 0.20658
# Epoch:   4, Batch:  80 , Avg. Loss: 0.23070
# Epoch:   4, Batch:  90 , Avg. Loss: 0.16430
# Epoch:   4, Batch:  100, Avg. Loss: 0.16468
# Epoch:   4, Batch:  110, Avg. Loss: 0.18516
# Epoch:   4, Batch:  120, Avg. Loss: 0.25782
# Epoch:   4, Batch:  130, Avg. Loss: 0.19573
# Epoch:   4, Batch:  140, Avg. Loss: 0.21826
# Epoch:   4, Batch:  150, Avg. Loss: 0.19382
# Epoch:   4, Batch:  160, Avg. Loss: 0.16245
# Epoch:   4, Batch:  170, Avg. Loss: 0.17910
# Epoch:   4, Batch:  180, Avg. Loss: 0.18526
# Epoch:   4, Batch:  190, Avg. Loss: 0.16634
# Epoch:   4, Batch:  200, Avg. Loss: 0.16639
# Epoch:   4, Batch:  210, Avg. Loss: 0.20453
# Epoch:   4, Batch:  220, Avg. Loss: 0.18427
# Epoch:   4, Batch:  230, Avg. Loss: 0.19038
# Epoch:   4, Batch:  240, Avg. Loss: 0.14693
# Epoch:   4, Batch:  250, Avg. Loss: 0.16620
# Epoch:   4, Batch:  260, Avg. Loss: 0.18092
# Epoch:   4, Batch:  270, Avg. Loss: 0.20534
# Epoch:   4, Batch:  280, Avg. Loss: 0.18432
# Epoch:   4, Batch:  290, Avg. Loss: 0.19128
# Epoch:   4, Batch:  300, Avg. Loss: 0.23069
# Epoch:   4, Batch:  310, Avg. Loss: 0.24295
# Epoch:   4, Batch:  320, Avg. Loss: 0.14761
# Epoch:   4, Batch:  330, Avg. Loss: 0.18084
# Epoch:   4, Batch:  340, Avg. Loss: 0.16661
# Epoch:   5, Batch:  10 , Avg. Loss: 0.18949
# Epoch:   5, Batch:  20 , Avg. Loss: 0.18969
# Epoch:   5, Batch:  30 , Avg. Loss: 0.20411
# Epoch:   5, Batch:  40 , Avg. Loss: 0.13752
# Epoch:   5, Batch:  50 , Avg. Loss: 0.25904
# Epoch:   5, Batch:  60 , Avg. Loss: 0.17680
# Epoch:   5, Batch:  70 , Avg. Loss: 0.17156
# Epoch:   5, Batch:  80 , Avg. Loss: 0.17459
# Epoch:   5, Batch:  90 , Avg. Loss: 0.16167
# Epoch:   5, Batch:  100, Avg. Loss: 0.15643
# Epoch:   5, Batch:  110, Avg. Loss: 0.21572
# Epoch:   5, Batch:  120, Avg. Loss: 0.17483
# Epoch:   5, Batch:  130, Avg. Loss: 0.25273
# Epoch:   5, Batch:  140, Avg. Loss: 0.17257
# Epoch:   5, Batch:  150, Avg. Loss: 0.22205
# Epoch:   5, Batch:  160, Avg. Loss: 0.18208
# Epoch:   5, Batch:  170, Avg. Loss: 0.15074
# Epoch:   5, Batch:  180, Avg. Loss: 0.16419
# Epoch:   5, Batch:  190, Avg. Loss: 0.14777
# Epoch:   5, Batch:  200, Avg. Loss: 0.19523
# Epoch:   5, Batch:  210, Avg. Loss: 0.17671
# Epoch:   5, Batch:  220, Avg. Loss: 0.16232
# Epoch:   5, Batch:  230, Avg. Loss: 0.18410
# Epoch:   5, Batch:  240, Avg. Loss: 0.23449
# Epoch:   5, Batch:  250, Avg. Loss: 0.17313
# Epoch:  10, Batch:  70 , Avg. Loss: 0.23939
# Epoch:  10, Batch:  80 , Avg. Loss: 0.17204
# Epoch:  10, Batch:  90 , Avg. Loss: 0.19903
# Epoch:  10, Batch:  100, Avg. Loss: 0.19189
# Epoch:  10, Batch:  110, Avg. Loss: 0.20843
# Epoch:  10, Batch:  120, Avg. Loss: 0.18076
# Epoch:  10, Batch:  130, Avg. Loss: 0.15792
# Epoch:  10, Batch:  140, Avg. Loss: 0.16054
# Epoch:  10, Batch:  150, Avg. Loss: 0.15893
# Epoch:  10, Batch:  160, Avg. Loss: 0.16096
# Epoch:  10, Batch:  170, Avg. Loss: 0.13540
# Epoch:  10, Batch:  180, Avg. Loss: 0.15996
# Epoch:  10, Batch:  190, Avg. Loss: 0.16553
# Epoch:  10, Batch:  200, Avg. Loss: 0.20507
# Epoch:  10, Batch:  210, Avg. Loss: 0.18946
# Epoch:  10, Batch:  220, Avg. Loss: 0.18010
# Epoch:  10, Batch:  230, Avg. Loss: 0.20905
# Epoch:  10, Batch:  240, Avg. Loss: 0.13967
# Epoch:  10, Batch:  250, Avg. Loss: 0.17393
# Epoch:  10, Batch:  260, Avg. Loss: 0.20908
# Epoch:  10, Batch:  270, Avg. Loss: 0.15031
# Epoch:  10, Batch:  280, Avg. Loss: 0.16575
# Epoch:  10, Batch:  290, Avg. Loss: 0.20654
# Epoch:  10, Batch:  300, Avg. Loss: 0.19766
# Epoch:  10, Batch:  310, Avg. Loss: 0.17647
# Epoch:  10, Batch:  320, Avg. Loss: 0.15505
# Epoch:  10, Batch:  330, Avg. Loss: 0.16839
# Epoch:  10, Batch:  340, Avg. Loss: 0.21342
# Epoch:  11, Batch:  10 , Avg. Loss: 0.22397
# Epoch:  11, Batch:  20 , Avg. Loss: 0.18095
# Epoch:  11, Batch:  30 , Avg. Loss: 0.17126
# Epoch:  11, Batch:  40 , Avg. Loss: 0.15723
# Epoch:  11, Batch:  50 , Avg. Loss: 0.32327
# Epoch:  11, Batch:  60 , Avg. Loss: 0.18545
# Epoch:  11, Batch:  70 , Avg. Loss: 0.18015
# Epoch:  11, Batch:  80 , Avg. Loss: 0.19420
# Epoch:  11, Batch:  90 , Avg. Loss: 0.18355
# Epoch:  11, Batch:  100, Avg. Loss: 0.42039
# Epoch:  11, Batch:  110, Avg. Loss: 0.18967
# Epoch:  11, Batch:  120, Avg. Loss: 0.18376
# Epoch:  11, Batch:  130, Avg. Loss: 0.18044
# Epoch:  11, Batch:  140, Avg. Loss: 0.19789
# Epoch:  11, Batch:  150, Avg. Loss: 0.16912
# Epoch:  11, Batch:  160, Avg. Loss: 0.16973
# Epoch:  11, Batch:  170, Avg. Loss: 0.17591
# Epoch:  11, Batch:  180, Avg. Loss: 0.22877
# Epoch:  11, Batch:  190, Avg. Loss: 0.15601
# Epoch:  11, Batch:  200, Avg. Loss: 0.17724
# Epoch:  11, Batch:  210, Avg. Loss: 0.20058
# Epoch:  11, Batch:  220, Avg. Loss: 0.18706
# Epoch:  11, Batch:  230, Avg. Loss: 0.17470
# Epoch:  17, Batch:  220, Avg. Loss: 0.21195
# Epoch:  17, Batch:  230, Avg. Loss: 0.23539
# Epoch:  17, Batch:  240, Avg. Loss: 0.14360
# Epoch:  17, Batch:  250, Avg. Loss: 0.19417
# Epoch:  17, Batch:  260, Avg. Loss: 0.16908
# Epoch:  17, Batch:  270, Avg. Loss: 0.15102
# Epoch:  17, Batch:  280, Avg. Loss: 0.16204
# Epoch:  17, Batch:  290, Avg. Loss: 0.24486
# Epoch:  17, Batch:  300, Avg. Loss: 0.20057
# Epoch:  17, Batch:  310, Avg. Loss: 0.24228
# Epoch:  17, Batch:  320, Avg. Loss: 0.19358
# Epoch:  17, Batch:  330, Avg. Loss: 0.19774
# Epoch:  17, Batch:  340, Avg. Loss: 0.19961
# Epoch:  18, Batch:  10 , Avg. Loss: 0.15796
# Epoch:  18, Batch:  20 , Avg. Loss: 0.18893
# Epoch:  18, Batch:  30 , Avg. Loss: 0.17450
# Epoch:  18, Batch:  40 , Avg. Loss: 0.18409
# Epoch:  18, Batch:  50 , Avg. Loss: 0.17566
# Epoch:  18, Batch:  60 , Avg. Loss: 0.18349
# Epoch:  18, Batch:  70 , Avg. Loss: 0.23554
# Epoch:  18, Batch:  80 , Avg. Loss: 0.15674
# Epoch:  18, Batch:  90 , Avg. Loss: 0.21074
# Epoch:  18, Batch:  100, Avg. Loss: 0.18910
# Epoch:  18, Batch:  110, Avg. Loss: 0.21188
# Epoch:  18, Batch:  120, Avg. Loss: 0.19920
# Epoch:  18, Batch:  130, Avg. Loss: 0.24667
# Epoch:  18, Batch:  140, Avg. Loss: 0.17908
# Epoch:  18, Batch:  150, Avg. Loss: 0.21708
# Epoch:  18, Batch:  160, Avg. Loss: 0.18253
# Epoch:  18, Batch:  170, Avg. Loss: 0.22456
# Epoch:  18, Batch:  180, Avg. Loss: 0.15389
# Epoch:  18, Batch:  190, Avg. Loss: 0.17753
# Epoch:  18, Batch:  200, Avg. Loss: 0.16307
# Epoch:  18, Batch:  210, Avg. Loss: 0.20086
# Epoch:  18, Batch:  220, Avg. Loss: 0.19443
# Epoch:  18, Batch:  230, Avg. Loss: 0.20669
# Epoch:  18, Batch:  240, Avg. Loss: 0.18823
# Epoch:  18, Batch:  250, Avg. Loss: 0.20936
# Epoch:  18, Batch:  260, Avg. Loss: 0.18190
# Epoch:  18, Batch:  270, Avg. Loss: 0.17907
# Epoch:  18, Batch:  280, Avg. Loss: 0.17415
# Epoch:  18, Batch:  290, Avg. Loss: 0.20080
# Epoch:  18, Batch:  300, Avg. Loss: 0.16141
# Epoch:  18, Batch:  310, Avg. Loss: 0.19583
# Epoch:  18, Batch:  320, Avg. Loss: 0.19845
# Epoch:  18, Batch:  330, Avg. Loss: 0.22573
# Epoch:  18, Batch:  340, Avg. Loss: 0.18084
# Epoch:  19, Batch:  10 , Avg. Loss: 0.22890
# Epoch:  19, Batch:  20 , Avg. Loss: 0.16820
# Epoch:  19, Batch:  30 , Avg. Loss: 0.21594
# Epoch:  19, Batch:  40 , Avg. Loss: 0.19511
# Epoch:  19, Batch:  50 , Avg. Loss: 0.17809
# Epoch:  19, Batch:  60 , Avg. Loss: 0.22003
# Epoch:  19, Batch:  70 , Avg. Loss: 0.17349
# Epoch:  19, Batch:  80 , Avg. Loss: 0.25061
# Epoch:  19, Batch:  90 , Avg. Loss: 0.22492
# Epoch:  19, Batch:  100, Avg. Loss: 0.21205
# Epoch:  19, Batch:  110, Avg. Loss: 0.16269
# Epoch:  19, Batch:  120, Avg. Loss: 0.25012
# Epoch:  19, Batch:  130, Avg. Loss: 0.15456
# Epoch:  19, Batch:  140, Avg. Loss: 0.15726
# Epoch:  19, Batch:  150, Avg. Loss: 0.20278
# Epoch:  19, Batch:  160, Avg. Loss: 0.19058
# Epoch:  19, Batch:  170, Avg. Loss: 0.21192
# Epoch:  19, Batch:  180, Avg. Loss: 0.17249
# Epoch:  19, Batch:  190, Avg. Loss: 0.19037
# Epoch:  19, Batch:  200, Avg. Loss: 0.17959
# Epoch:  19, Batch:  210, Avg. Loss: 0.15602
# Epoch:  19, Batch:  220, Avg. Loss: 0.22234
# Epoch:  19, Batch:  230, Avg. Loss: 0.16599
# Epoch:  19, Batch:  240, Avg. Loss: 0.22530
# Epoch:  19, Batch:  250, Avg. Loss: 0.22321
# Epoch:  19, Batch:  260, Avg. Loss: 0.24880
# Epoch:  19, Batch:  270, Avg. Loss: 0.17862
# Epoch:  19, Batch:  280, Avg. Loss: 0.15851
# Epoch:  19, Batch:  290, Avg. Loss: 0.19919
# Epoch:  19, Batch:  300, Avg. Loss: 0.16812
# Epoch:  19, Batch:  310, Avg. Loss: 0.15718
# Epoch:  19, Batch:  320, Avg. Loss: 0.17755
# Epoch:  19, Batch:  330, Avg. Loss: 0.16598
# Epoch:  19, Batch:  340, Avg. Loss: 0.23121
# Epoch:  20, Batch:  10 , Avg. Loss: 0.32460
# Epoch:  20, Batch:  20 , Avg. Loss: 0.16886
# Epoch:  20, Batch:  30 , Avg. Loss: 0.15068
# Epoch:  20, Batch:  40 , Avg. Loss: 0.19886
# Epoch:  20, Batch:  50 , Avg. Loss: 0.22312
# Epoch:  20, Batch:  60 , Avg. Loss: 0.15288
# Epoch:  20, Batch:  70 , Avg. Loss: 0.22061
# Epoch:  20, Batch:  80 , Avg. Loss: 0.16303
# Epoch:  20, Batch:  90 , Avg. Loss: 0.19148
# Epoch:  20, Batch:  100, Avg. Loss: 0.17733
# Epoch:  20, Batch:  110, Avg. Loss: 0.18314
# Epoch:  20, Batch:  120, Avg. Loss: 0.18676
# Epoch:  20, Batch:  130, Avg. Loss: 0.15984
# Epoch:  20, Batch:  140, Avg. Loss: 0.19229
# Epoch:  20, Batch:  150, Avg. Loss: 0.20162
# Epoch:  20, Batch:  160, Avg. Loss: 0.17262
# Epoch:  20, Batch:  170, Avg. Loss: 0.18778
# Epoch:  20, Batch:  180, Avg. Loss: 0.26285
# Epoch:  20, Batch:  190, Avg. Loss: 0.16720
# Epoch:  20, Batch:  200, Avg. Loss: 0.16695
# Epoch:  20, Batch:  210, Avg. Loss: 0.18318
# Epoch:  20, Batch:  220, Avg. Loss: 0.23299
# Epoch:  20, Batch:  230, Avg. Loss: 0.20299
# Epoch:  20, Batch:  240, Avg. Loss: 0.15890
# Epoch:  20, Batch:  250, Avg. Loss: 0.18670
# Epoch:  20, Batch:  260, Avg. Loss: 0.22644
# Epoch:  20, Batch:  270, Avg. Loss: 0.25619
# Epoch:  20, Batch:  280, Avg. Loss: 0.15144
# Epoch:  20, Batch:  290, Avg. Loss: 0.16505
# Epoch:  20, Batch:  300, Avg. Loss: 0.15103
# Epoch:  20, Batch:  310, Avg. Loss: 0.16318
# Epoch:  20, Batch:  320, Avg. Loss: 0.18551
# Epoch:  20, Batch:  330, Avg. Loss: 0.16978
# Epoch:  20, Batch:  340, Avg. Loss: 0.17485
# Epoch:  21, Batch:  10 , Avg. Loss: 0.17724
# Epoch:  21, Batch:  20 , Avg. Loss: 0.13363
# Epoch:  21, Batch:  30 , Avg. Loss: 0.23777
# Epoch:  21, Batch:  40 , Avg. Loss: 0.16097
# Epoch:  21, Batch:  50 , Avg. Loss: 0.17317
# Epoch:  21, Batch:  60 , Avg. Loss: 0.20231
# Epoch:  21, Batch:  70 , Avg. Loss: 0.16377
# Epoch:  21, Batch:  80 , Avg. Loss: 0.19203
# Epoch:  21, Batch:  90 , Avg. Loss: 0.17463
# Epoch:  21, Batch:  100, Avg. Loss: 0.24135
# Epoch:  21, Batch:  110, Avg. Loss: 0.21239
# Epoch:  21, Batch:  120, Avg. Loss: 0.18312
# Epoch:  21, Batch:  130, Avg. Loss: 0.17557
# Epoch:  21, Batch:  140, Avg. Loss: 0.30569
# Epoch:  21, Batch:  150, Avg. Loss: 0.19481
# Epoch:  21, Batch:  160, Avg. Loss: 0.18373
# Epoch:  21, Batch:  170, Avg. Loss: 0.19485
# Epoch:  21, Batch:  180, Avg. Loss: 0.18479
# Epoch:  21, Batch:  190, Avg. Loss: 0.23158
# Epoch:  21, Batch:  200, Avg. Loss: 0.17715
# Epoch:  21, Batch:  210, Avg. Loss: 0.22800
# Epoch:  21, Batch:  220, Avg. Loss: 0.17735
# Epoch:  21, Batch:  230, Avg. Loss: 0.19286
# Epoch:  21, Batch:  240, Avg. Loss: 0.17438
# Epoch:  21, Batch:  250, Avg. Loss: 0.19979
# Epoch:  21, Batch:  260, Avg. Loss: 0.15949
# Epoch:  21, Batch:  270, Avg. Loss: 0.19532
# Epoch:  21, Batch:  280, Avg. Loss: 0.18326
# Epoch:  21, Batch:  290, Avg. Loss: 0.20173
# Epoch:  21, Batch:  300, Avg. Loss: 0.16781
# Epoch:  21, Batch:  310, Avg. Loss: 0.14125
# Epoch:  21, Batch:  320, Avg. Loss: 0.18646
# Epoch:  21, Batch:  330, Avg. Loss: 0.26652
# Epoch:  21, Batch:  340, Avg. Loss: 0.17721
# Epoch:  22, Batch:  10 , Avg. Loss: 0.25460
# Epoch:  22, Batch:  20 , Avg. Loss: 0.17153
# Epoch:  22, Batch:  30 , Avg. Loss: 0.15858
# Epoch:  22, Batch:  40 , Avg. Loss: 0.20045
# Epoch:  22, Batch:  50 , Avg. Loss: 0.18510
# Epoch:  22, Batch:  60 , Avg. Loss: 0.18429
# Epoch:  22, Batch:  70 , Avg. Loss: 0.20120
# Epoch:  22, Batch:  80 , Avg. Loss: 0.18226
# Epoch:  22, Batch:  90 , Avg. Loss: 0.19716
# Epoch:  22, Batch:  100, Avg. Loss: 0.16470
# Epoch:  22, Batch:  110, Avg. Loss: 0.20216
# Epoch:  22, Batch:  120, Avg. Loss: 0.14308
# Epoch:  22, Batch:  130, Avg. Loss: 0.24007
# Epoch:  22, Batch:  140, Avg. Loss: 0.15398
# Epoch:  22, Batch:  150, Avg. Loss: 0.19675
# Epoch:  22, Batch:  160, Avg. Loss: 0.14226
# Epoch:  22, Batch:  170, Avg. Loss: 0.16450
# Epoch:  22, Batch:  180, Avg. Loss: 0.19195
# Epoch:  22, Batch:  190, Avg. Loss: 0.18394
# Epoch:  22, Batch:  200, Avg. Loss: 0.18579
# Epoch:  22, Batch:  210, Avg. Loss: 0.22785
# Epoch:  22, Batch:  220, Avg. Loss: 0.22830
# Epoch:  22, Batch:  230, Avg. Loss: 0.16223
# Epoch:  22, Batch:  240, Avg. Loss: 0.18434
# Epoch:  22, Batch:  250, Avg. Loss: 0.21039
# Epoch:  22, Batch:  260, Avg. Loss: 0.15721
# Epoch:  22, Batch:  270, Avg. Loss: 0.15647
# Epoch:  22, Batch:  280, Avg. Loss: 0.18924
# Epoch:  22, Batch:  290, Avg. Loss: 0.20456
# Epoch:  22, Batch:  300, Avg. Loss: 0.20851
# Epoch:  22, Batch:  310, Avg. Loss: 0.19353
# Epoch:  22, Batch:  320, Avg. Loss: 0.21629
# Epoch:  22, Batch:  330, Avg. Loss: 0.15362
# Epoch:  22, Batch:  340, Avg. Loss: 0.19410
# Epoch:  23, Batch:  10 , Avg. Loss: 0.34599
# Epoch:  23, Batch:  20 , Avg. Loss: 0.17697
# Epoch:  23, Batch:  30 , Avg. Loss: 0.19903
# Epoch:  23, Batch:  40 , Avg. Loss: 0.21427
# Epoch:  23, Batch:  50 , Avg. Loss: 0.18774
# Epoch:  23, Batch:  60 , Avg. Loss: 0.16981
# Epoch:  23, Batch:  70 , Avg. Loss: 0.21643
# Epoch:  23, Batch:  80 , Avg. Loss: 0.22754
# Epoch:  23, Batch:  90 , Avg. Loss: 0.16910
# Epoch:  23, Batch:  100, Avg. Loss: 0.18417
# Epoch:  23, Batch:  110, Avg. Loss: 0.20353
# Epoch:  23, Batch:  120, Avg. Loss: 0.18962
# Epoch:  23, Batch:  130, Avg. Loss: 0.20195
# Epoch:  23, Batch:  140, Avg. Loss: 0.19204
# Epoch:  23, Batch:  150, Avg. Loss: 0.20060
# Epoch:  23, Batch:  160, Avg. Loss: 0.17247
# Epoch:  23, Batch:  170, Avg. Loss: 0.21805
# Epoch:  23, Batch:  180, Avg. Loss: 0.19680
# Epoch:  25, Batch:  20 , Avg. Loss: 0.22640
# Epoch:  25, Batch:  30 , Avg. Loss: 0.16265
# Epoch:  25, Batch:  40 , Avg. Loss: 0.17099
# Epoch:  25, Batch:  50 , Avg. Loss: 0.18370
# Epoch:  25, Batch:  60 , Avg. Loss: 0.17534
# Epoch:  25, Batch:  70 , Avg. Loss: 0.16068
# Epoch:  25, Batch:  80 , Avg. Loss: 0.16049
# Epoch:  25, Batch:  90 , Avg. Loss: 0.18395
# Epoch:  25, Batch:  100, Avg. Loss: 0.16443
# Epoch:  25, Batch:  110, Avg. Loss: 0.20005
# Epoch:  25, Batch:  120, Avg. Loss: 0.22174
# Epoch:  25, Batch:  130, Avg. Loss: 0.22230
# Epoch:  25, Batch:  140, Avg. Loss: 0.19350
# Epoch:  25, Batch:  150, Avg. Loss: 0.16230
# Epoch:  25, Batch:  160, Avg. Loss: 0.17207
# Epoch:  25, Batch:  170, Avg. Loss: 0.15025
# Epoch:  25, Batch:  180, Avg. Loss: 0.19168
# Epoch:  25, Batch:  190, Avg. Loss: 0.21153
# Epoch:  25, Batch:  200, Avg. Loss: 0.24230
# Epoch:  25, Batch:  210, Avg. Loss: 0.16245
# Epoch:  25, Batch:  220, Avg. Loss: 0.18247
# Epoch:  25, Batch:  230, Avg. Loss: 0.16823
# Epoch:  25, Batch:  240, Avg. Loss: 0.22199
# Epoch:  25, Batch:  250, Avg. Loss: 0.17259
# Epoch:  25, Batch:  260, Avg. Loss: 0.13928
# Epoch:  25, Batch:  270, Avg. Loss: 0.19833
# Epoch:  25, Batch:  280, Avg. Loss: 0.28979
# Epoch:  25, Batch:  290, Avg. Loss: 0.18329
# Epoch:  25, Batch:  300, Avg. Loss: 0.17494
# Epoch:  25, Batch:  310, Avg. Loss: 0.16774
# Epoch:  25, Batch:  320, Avg. Loss: 0.22467
# Epoch:  25, Batch:  330, Avg. Loss: 0.19416
# Epoch:  25, Batch:  340, Avg. Loss: 0.23407
# Epoch:  26, Batch:  10 , Avg. Loss: 0.25431
# Epoch:  26, Batch:  20 , Avg. Loss: 0.19907
# Epoch:  26, Batch:  30 , Avg. Loss: 0.18387
# Epoch:  26, Batch:  40 , Avg. Loss: 0.13500
# Epoch:  26, Batch:  50 , Avg. Loss: 0.25392
# Epoch:  26, Batch:  60 , Avg. Loss: 0.14850
# Epoch:  26, Batch:  70 , Avg. Loss: 0.21493
# Epoch:  26, Batch:  80 , Avg. Loss: 0.18833
# Epoch:  26, Batch:  90 , Avg. Loss: 0.21636
# Epoch:  26, Batch:  100, Avg. Loss: 0.17747
# Epoch:  26, Batch:  110, Avg. Loss: 0.18297
# Epoch:  26, Batch:  120, Avg. Loss: 0.15292
# Epoch:  26, Batch:  130, Avg. Loss: 0.19713
# Epoch:  26, Batch:  140, Avg. Loss: 0.19967
# Epoch:  26, Batch:  150, Avg. Loss: 0.17483
# Epoch:  26, Batch:  160, Avg. Loss: 0.16530
# Epoch:  26, Batch:  170, Avg. Loss: 0.16643
# Epoch:  26, Batch:  180, Avg. Loss: 0.19617
# Epoch:  26, Batch:  190, Avg. Loss: 0.17054
# Epoch:  26, Batch:  200, Avg. Loss: 0.18249
# Epoch:  26, Batch:  210, Avg. Loss: 0.20704
# Epoch:  26, Batch:  220, Avg. Loss: 0.15744
# Epoch:  26, Batch:  230, Avg. Loss: 0.19828
# Epoch:  26, Batch:  240, Avg. Loss: 0.16554
# Epoch:  26, Batch:  250, Avg. Loss: 0.14355
# Epoch:  26, Batch:  260, Avg. Loss: 0.18269
# Epoch:  26, Batch:  270, Avg. Loss: 0.16191
# Epoch:  26, Batch:  280, Avg. Loss: 0.16877
# Epoch:  26, Batch:  290, Avg. Loss: 0.18541
# Epoch:  26, Batch:  300, Avg. Loss: 0.18946
# Epoch:  26, Batch:  310, Avg. Loss: 0.17797
# Epoch:  26, Batch:  320, Avg. Loss: 0.25323
# Epoch:  26, Batch:  330, Avg. Loss: 0.18765
# Epoch:  26, Batch:  340, Avg. Loss: 0.18611
# Epoch:  27, Batch:  10 , Avg. Loss: 0.21043
# Epoch:  27, Batch:  20 , Avg. Loss: 0.20883
# Epoch:  27, Batch:  30 , Avg. Loss: 0.17112
# Epoch:  27, Batch:  40 , Avg. Loss: 0.17844
# Epoch:  27, Batch:  50 , Avg. Loss: 0.17504
# Epoch:  27, Batch:  60 , Avg. Loss: 0.15824
# Epoch:  27, Batch:  70 , Avg. Loss: 0.17829
# Epoch:  27, Batch:  80 , Avg. Loss: 0.13622
# Epoch:  27, Batch:  90 , Avg. Loss: 0.17261
# Epoch:  27, Batch:  100, Avg. Loss: 0.19599
# Epoch:  27, Batch:  110, Avg. Loss: 0.19713
# Epoch:  27, Batch:  120, Avg. Loss: 0.16374
# Epoch:  27, Batch:  130, Avg. Loss: 0.15315
# Epoch:  27, Batch:  140, Avg. Loss: 0.25947
# Epoch:  27, Batch:  150, Avg. Loss: 0.19515
# Epoch:  27, Batch:  160, Avg. Loss: 0.21194
# Epoch:  27, Batch:  170, Avg. Loss: 0.20625
# Epoch:  27, Batch:  180, Avg. Loss: 0.17516
# Epoch:  27, Batch:  190, Avg. Loss: 0.19385
# Epoch:  27, Batch:  200, Avg. Loss: 0.19268
# Epoch:  27, Batch:  210, Avg. Loss: 0.20848
# Epoch:  27, Batch:  220, Avg. Loss: 0.17457
# Epoch:  27, Batch:  230, Avg. Loss: 0.18278
# Epoch:  27, Batch:  240, Avg. Loss: 0.25841
# Epoch:  27, Batch:  250, Avg. Loss: 0.16721
# Epoch:  27, Batch:  260, Avg. Loss: 0.18639
# Epoch:  27, Batch:  270, Avg. Loss: 0.20303
# Epoch:  27, Batch:  280, Avg. Loss: 0.18103
# Epoch:  27, Batch:  290, Avg. Loss: 0.18551
# Epoch:  27, Batch:  300, Avg. Loss: 0.21499
# Epoch:  27, Batch:  310, Avg. Loss: 0.19644
# Epoch:  27, Batch:  320, Avg. Loss: 0.20207
# Epoch:  27, Batch:  330, Avg. Loss: 0.16082
# Epoch:  27, Batch:  340, Avg. Loss: 0.15319
# Epoch:  28, Batch:  10 , Avg. Loss: 0.19887
# Epoch:  28, Batch:  20 , Avg. Loss: 0.19078
# Epoch:  28, Batch:  30 , Avg. Loss: 0.18152
# Epoch:  28, Batch:  40 , Avg. Loss: 0.21075
# Epoch:  28, Batch:  50 , Avg. Loss: 0.31096
# Epoch:  28, Batch:  60 , Avg. Loss: 0.15442
# Epoch:  28, Batch:  70 , Avg. Loss: 0.19887
# Epoch:  28, Batch:  80 , Avg. Loss: 0.19053
# Epoch:  28, Batch:  90 , Avg. Loss: 0.16759
# Epoch:  28, Batch:  100, Avg. Loss: 0.16923
# Epoch:  28, Batch:  110, Avg. Loss: 0.16509
# Epoch:  28, Batch:  120, Avg. Loss: 0.19935
# Epoch:  28, Batch:  130, Avg. Loss: 0.20572
# Epoch:  28, Batch:  140, Avg. Loss: 0.20708
# Epoch:  28, Batch:  150, Avg. Loss: 0.18784
# Epoch:  28, Batch:  160, Avg. Loss: 0.22176
# Epoch:  28, Batch:  170, Avg. Loss: 0.17978
# Epoch:  28, Batch:  180, Avg. Loss: 0.20210
# Epoch:  28, Batch:  190, Avg. Loss: 0.19014
# Epoch:  28, Batch:  200, Avg. Loss: 0.18804
# Epoch:  28, Batch:  210, Avg. Loss: 0.17308
# Epoch:  28, Batch:  220, Avg. Loss: 0.14756
# Epoch:  28, Batch:  230, Avg. Loss: 0.17847
# Epoch:  28, Batch:  240, Avg. Loss: 0.15884
# Epoch:  28, Batch:  250, Avg. Loss: 0.19767
# Epoch:  28, Batch:  260, Avg. Loss: 0.17096
# Epoch:  28, Batch:  270, Avg. Loss: 0.16293
# Epoch:  28, Batch:  280, Avg. Loss: 0.25314
# Epoch:  28, Batch:  290, Avg. Loss: 0.15168
# Epoch:  28, Batch:  300, Avg. Loss: 0.27564
# Epoch:  28, Batch:  310, Avg. Loss: 0.19079
# Epoch:  28, Batch:  320, Avg. Loss: 0.21411
# Epoch:  28, Batch:  330, Avg. Loss: 0.15689
# Epoch:  28, Batch:  340, Avg. Loss: 0.19261
# Epoch:  29, Batch:  10 , Avg. Loss: 0.17392
# Epoch:  29, Batch:  20 , Avg. Loss: 0.20955
# Epoch:  29, Batch:  30 , Avg. Loss: 0.20657
# Epoch:  29, Batch:  40 , Avg. Loss: 0.22707
# Epoch:  29, Batch:  50 , Avg. Loss: 0.27487
# Epoch:  29, Batch:  60 , Avg. Loss: 0.19621
# Epoch:  29, Batch:  70 , Avg. Loss: 0.17569
# Epoch:  29, Batch:  80 , Avg. Loss: 0.17118
# Epoch:  29, Batch:  90 , Avg. Loss: 0.17831
# Epoch:  29, Batch:  100, Avg. Loss: 0.19445
# Epoch:  29, Batch:  110, Avg. Loss: 0.35599
# Epoch:  29, Batch:  120, Avg. Loss: 0.16145
# Epoch:  29, Batch:  130, Avg. Loss: 0.15308
# Epoch:  29, Batch:  140, Avg. Loss: 0.19743
# Epoch:  29, Batch:  150, Avg. Loss: 0.21037
# Epoch:  29, Batch:  160, Avg. Loss: 0.19736
plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Test data
#
# See how your model performs on previously unseen, test data. We've already loaded and transformed this data, similar to the training data. Next, run your trained model on these images to see what kind of keypoints are produced. You should be able to see if your model is fitting each new face it sees, if the points are distributed randomly, or if the points have actually overfitted the training data and do not generalize.

# %%
# get a sample of test data again
net.cpu()
test_images, test_outputs, gt_pts = net_sample_output()

print(test_images.data.size())
print(test_outputs.data.size())
print(gt_pts.size())
# Out:
# torch.Size([10, 1, 224, 224])
# torch.Size([10, 68, 2])
# torch.Size([10, 68, 2])

# %%
## TODO: visualize your test output
# you can use the same function as before, by un-commenting the line below:

visualize_output(test_images, test_outputs, gt_pts)

# %% [markdown]
# Once you've found a good model (or two), save your model so you can load it and use it later!
#
# Save your models but please **delete any checkpoints and saved models before you submit your project** otherwise your workspace may be too large to submit.

# %%
## TODO: change the name to something unique for each new model
from datetime import datetime
now = datetime.now().strftime('%Y%m%dT%H%M%S')
model_dir = 'saved_models/'
model_name = f'keypoints_model_{now}'

# after training, save your model parameters in the dir 'saved_models'
torch.save(net.state_dict(), model_dir+model_name)

# %% [markdown]
# After you've trained a well-performing model, answer the following questions so that we have some insight into your training and architecture selection process. Answering all questions is required to pass this project.

# %% [markdown]
# ### Question 1: What optimization and loss functions did you choose and why?

# %% [markdown]
# **Answer**: write your answer here (double click to edit this cell)
#
# #### Response
#
# I chose to use an Adam optimizer, as I am the most familiar with the
# optimizer and it's learning rates and felt that this would be an
# appropriate choice for the task.
#
# I also chose to use a Mean Squared Error loss model as I wanted the
# loss to punish deviations with large euclidean distance away from the
# key points, and I wasn't worried about low loss values when
# deviations are small.

# %% [markdown]
# ### Question 2: What kind of network architecture did you start with and how did it change as you tried different architectures? Did you decide to add more convolutional layers or any layers to avoid overfitting the data?

# %% [markdown]
# **Answer**: write your answer here
#
# #### Initial Design
#
# I started with a convolutional using a 3x3 convolution with 0
# additional padding and a stride of 1. Effectively decreasing the width
# and height by 2 each pass. Each Convolutional layer increased the
# depth first from the 1-deep gray scale input image to a 32 filter-depth
# layer and subsequently increasing each layer by a factor of two to a
# 256-deep convolutional layer. Directly after the convolutional layer was applied, a ReLU activation function was applied.
#
# In between each convolutional layer I added max pooling layers with a
# 2x2 kernel and a stride of 2, effectively decreasing the width and
# height by half each pass. After max pooling, dropout was added with a
# 20% probability to prevent over-fitting.
#
# The 256-deep convolutional layer was then flattened to feed into a
# fully connected layer where two layers of equal depth (1024) were added with the same dropout and activation functions. Finally, the
# last hidden layer fed into the output layer where 68 nodes were
# selected to fit the requirements of the project and a tanh activation
# function was used to limit the output between [-1, 1]. (Note: a
# threshold function was considered and the model performance was
# monitored to evaluate the correct final activation function.)
#
# #### Final Design
#
# I went through several iterations and ended up with ...
#
# TODO FIXME

# %% [markdown]
# ### Question 3: How did you decide on the number of epochs and batch_size to train your model?

# %% [markdown]
# **Answer**: write your answer here
#
# #### Response
#
# I determined batch_size to a large enough batch that could still fit on my available resources.
#
# Epoch was determined to be long enough where training was still progressing and halted prior to overtraining. As shown by stagnation of learning (and increase in validation losses)

# %% [markdown]
# ## Feature Visualization
#
# Sometimes, neural networks are thought of as a black box, given some input, they learn to produce some output. CNN's are actually learning to recognize a variety of spatial patterns and you can visualize what each convolutional layer has been trained to recognize by looking at the weights that make up each convolutional kernel and applying those one at a time to a sample image. This technique is called feature visualization and it's useful for understanding the inner workings of a CNN.

# %% [markdown]
# In the cell below, you can see how to extract a single filter (by index) from your first convolutional layer. The filter should appear as a grayscale grid.

# %%
# Get the weights in the first conv layer, "conv1"
# if necessary, change this to reflect the name of your first conv layer
# CITATION: from Udacity's Computer Vision Course
n_layers = 4
CONV_LAYER = 0
net.cpu()
weights = [net.conv[layer][CONV_LAYER].weight.data for layer in range(n_layers)]

w = weights[0].numpy()

filter_index = 2

print(w[filter_index][0])
print(w[filter_index][0].shape)

# display the filter weights
plt.imshow(w[filter_index][0], cmap='gray')

fig = plt.figure(figsize=(16, 16))
more_w = weights[0].numpy()
cols = 3
rows = 3
print(f'First {cols*rows} filters from the first Conv layer')
for i in range(0, cols*rows):
    fig.add_subplot(rows, cols, i+1)
    plt.imshow(more_w[i][0], cmap='gray')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_21680/608338500.py in <module>
#       4 n_layers = 4
#       5 CONV_LAYER = 0
# ----> 6 net.cpu()
#       7 weights = [net.conv[layer][CONV_LAYER].weight.data for layer in range(n_layers)]
#       8
#
# NameError: name 'net' is not defined

# %% [markdown]
# ## Feature maps
#
# Each CNN has at least one convolutional layer that is composed of stacked filters (also known as convolutional kernels). As a CNN trains, it learns what weights to include in it's convolutional kernels and when these kernels are applied to some input image, they produce a set of **feature maps**. So, feature maps are just sets of filtered images; they are the images produced by applying a convolutional kernel to an input image. These maps show us the features that the different layers of the neural network learn to extract. For example, you might imagine a convolutional kernel that detects the vertical edges of a face or another one that detects the corners of eyes. You can see what kind of features each of these kernels detects by applying them to an image. One such example is shown below; from the way it brings out the lines in an the image, you might characterize this as an edge detection filter.
#
# <img src='images/feature_map_ex.png' width=50% height=50%/>
#
#
# Next, choose a test image and filter it with one of the convolutional kernels in your trained CNN; look at the filtered output to get an idea what that particular kernel detects.
#
# ### TODO: Filter an image to see the effect of a convolutional kernel
# ---

# %%
##TODO: load in and display any image from the transformed test dataset

## TODO: Using cv's filter2D function,
## apply a specific set of filter weights (like the one displayed above) to the test image
# CITATION: from Udacity Computer Vision Course
import matplotlib.image as mpimg
import cv2
test_images, _, _ = net_sample_output()

idx = 4
img = np.squeeze(test_images[idx].numpy())

w = weights[0][0].numpy()
weights = net.conv[0][0].weight.data
filter_idx = 0
this_filter = w[filter_idx][0]


c_img = cv2.filter2D(img, -1, this_filter)

# %%
# fig = plt.figure(figsize=(8, 16))
fig, (ax1, ax2) = plt.subplots(1, 2)
ax1.imshow(img, cmap='gray')
ax1.set_title('Original')

ax2.imshow(c_img, cmap='gray')
ax2.set_title('Filtered')
plt.show()

# %% [markdown]
# ### Question 4: Choose one filter from your trained CNN and apply it to a test image; what purpose do you think it plays? What kind of feature do you think it detects?

# %% [markdown]
# **Answer**: (does it detect vertical lines or does it blur out noise, etc.) write your answer here
#
# #### Response
#
# The above filter appears to be a rising edge detector, highlighting features
# that move from low values (left) to high values (right). There seems to be some
# components in direction that is not strictly left-right, but this seems to be
# the prominant feature.

# %% [markdown]
# ---
# ## Moving on!
#
# Now that you've defined and trained your model (and saved the best model), you are ready to move on to the last notebook, which combines a face detector with your saved model to create a facial keypoint detection system that can predict the keypoints on *any* face in an image!
